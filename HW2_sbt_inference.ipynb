# %% [markdown]
# # ДЗ 2

# %% [markdown]
# В этом задании нужно будет обучить архитектуру для задачи Image Classification. Вам нужно будет реализовать архитектуру, обучить ее, а так же выполнить некоторые дополнительные задания.

# %% [markdown]
# В качестве датасета будет использовать вот этот - https://www.kaggle.com/datasets/slothkong/10-monkey-species

# %%
# Кажется, у меня проблемы с драйверами для видеокарты, из-за чего обучение может в произвольный момент падать
# Запрет асинхронных запусков ядра не решает проблему полностью, но заметно снижает вероятность её возникновения
import os
os.environ['CUDA_LAUNCH_BLOCKING']="1"

# %% [markdown]
# # Dataset

# %% [markdown]
# ## Download from Kaggle

# %%
import zipfile
import shutil
import json
import os

# %%
with open('kaggle.json') as f:
    account = json.load(f)
    os.environ['KAGGLE_USERNAME'] = account["username"]
    os.environ['KAGGLE_KEY'] = account["key"]
import kaggle

# %%
def clear_directory(path_to_dir: str, force: bool):
    if force and os.path.exists(path_to_dir):
        shutil.rmtree(path_to_dir)
    if force or not os.path.exists(path_to_dir):
        os.makedirs(path_to_dir)
        return True
    if not os.listdir(path_to_dir):
        return True
    
    return False

# %%
def download_dataset_from_kaggle(kaggle_dataset_id: str, out_directory: str, overwrite: bool = False):
    if not clear_directory(out_directory, overwrite):
        print("Directory is already occupied")
        return
    
    kaggle.api.dataset_download_files(kaggle_dataset_id,
                                      path=out_directory,
                                      quiet=False)
    filename = f"{out_directory}/{kaggle_dataset_id.split('/')[-1]}.zip"
    with zipfile.ZipFile(filename, 'r') as zip_ref:
        zip_ref.extractall(out_directory)
    os.remove(filename)

# %%
dataset_name = "slothkong/10-monkey-species"
data_path = "./data"
download_dataset_from_kaggle(dataset_name, data_path)
# Out:
# Directory is already occupied

# %% [markdown]
# ## Prepare torch dataset

# %%
from sklearn.metrics import classification_report
from matplotlib import pyplot as plt
from pytorch_lightning.callbacks import ModelCheckpoint
from torch.utils.data import DataLoader
import torch
import numpy as np
from torchvision import transforms
from torchvision.datasets import ImageFolder
import torchvision
import torchvision.models as models
import pytorch_lightning as pl
import torch.nn as nn
from torchmetrics import Accuracy
from collections import Counter
import random
import cv2

# %%
SEED = 666

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %%
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

class AlbumentationsDataset(ImageFolder):
    def __init__(self, root: str, transform = None):
        super().__init__(root, transform=transform)
        self.imgs = self.samples

    def __getitem__(self, index: int):
        """
        Args:
            index (int): Index

        Returns:
            tuple: (sample, target) where target is class_index of the target class.
        """
        path, target = self.imgs[index]
        sample = cv2.imread(path)
        sample = cv2.cvtColor(sample, cv2.COLOR_BGR2RGB)
        if self.transform is not None:
            sample = self.transform(image=sample)["image"]
        return sample, target

# %%
train_transforms = A.Compose([
        A.HorizontalFlip(),
        A.RandomRotate90(),
        A.ShiftScaleRotate(rotate_limit=20, scale_limit=0.2),
        A.Resize(224, 224),
        A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        ToTensorV2()
])

resnet_train_transforms = A.Compose([
        A.HorizontalFlip(),
        A.RandomRotate90(),
        A.Resize(224, 224),
        A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        ToTensorV2()
])

inception_train_transforms = A.Compose([
        A.HorizontalFlip(),
        A.RandomRotate90(),
        A.Resize(518, 518),
        A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        ToTensorV2()
])

# %%
val_transforms = transforms.Compose([
            transforms.Resize(size=(224,224)),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
        ])

resnet_val_transforms = transforms.Compose([
            transforms.Resize((224,224)),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
        ])

inception_val_transforms = transforms.Compose([
            transforms.Resize((518,518)),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
        ])

# %%
train_ds = AlbumentationsDataset('./data/training/training/', transform=train_transforms)
val_ds = ImageFolder('./data/validation/validation/', transform=val_transforms)

# %%
resnet_train_ds = AlbumentationsDataset('./data/training/training/', transform=resnet_train_transforms)
resnet_val_ds = ImageFolder('./data/validation/validation/', transform=resnet_val_transforms)

# %%
inception_train_ds = AlbumentationsDataset('./data/training/training/', transform=inception_train_transforms)
inception_val_ds = ImageFolder('./data/validation/validation/', transform=inception_val_transforms)

# %%
print(f'Class statistics in train dataset: {Counter(train_ds.targets)}')
print(f'Class statistics in train dataset: {Counter(val_ds.targets)}')
# Out:
# Class statistics in train dataset: Counter({3: 122, 7: 114, 5: 113, 1: 111, 2: 110, 6: 106, 8: 106, 0: 105, 4: 105, 9: 105})
# Class statistics in train dataset: Counter({3: 30, 1: 28, 5: 28, 7: 28, 2: 27, 8: 27, 0: 26, 4: 26, 6: 26, 9: 26})

# %% [markdown]
# # Dataloader

# %%
CONFIG = {"lr": 2e-4,
          "batch_size": 32,
          "epochs": 200,
          "div_factor": 1e+5}

# %%
train_dl = DataLoader(train_ds, batch_size=CONFIG['batch_size'], shuffle=True, num_workers=4)
val_dl = DataLoader(val_ds, batch_size=CONFIG['batch_size'], shuffle=False, num_workers=4)

# %%
resnet_train_dl = DataLoader(resnet_train_ds, batch_size=16, shuffle=True, num_workers=4)
resnet_val_dl = DataLoader(resnet_val_ds, batch_size=16, shuffle=False, num_workers=4)

# %%
inception_train_dl = DataLoader(inception_train_ds, batch_size=4, shuffle=True, num_workers=4)
inception_val_dl = DataLoader(inception_val_ds, batch_size=4, shuffle=False, num_workers=4)

# %%
id2clas = {i:q for q,i in train_ds.class_to_idx.items()}

# %%
NUM_IMAGES = 4
samples = [train_ds[idx] for idx in np.random.choice(np.arange(0, len(train_ds)), NUM_IMAGES, replace=False)]
images = [i[0] for i in samples]
labels = [id2clas[i[1]] for i in samples]

img_grid = torchvision.utils.make_grid(images, nrow=NUM_IMAGES, normalize=True, pad_value=0.5)
img_grid = img_grid.permute(1, 2, 0)

plt.figure(figsize=(8, 8))
plt.imshow(img_grid)
plt.axis("off")
plt.show()
plt.close()
print(labels)
# Out:
# ['n8', 'n1', 'n8', 'n9']

# %% [markdown]
# ## VGG.

# %% [markdown]
# Реализуйте VGG16 from scratch. Чтобы вспомнить архитектуру, обратитесь к лекции + оригинальной статье авторов+google.
#
# Если хотите реализовать что-то поинтереснее (resnet, ViT???) - делайте, будет учтено.

# %% [markdown]
# Что будет оцениваться в задании:
# * VGG16 from scratch **6 баллов**
# * добавьте аугментаций, напишите краткое саммари почему выбрали именно такой набор аугментаций. **1 балл**
# * дописать логику обучения модели **2 балла**
# * дописать логику тестирования модели **1 балл**
# * возьмите еще 2 модели из зоопарка моделей [torchvision](https://pytorch.org/vision/stable/models.html?), зафайнтюньте на наш датасет. Сравните их между собой и вашей реализацией. **4 балла**
# * обязательно в конце напишите общий отчет о проделанной работе. Для лучшей модели проведите анализ метрик и ошибок, постройте confusion_matrix и classification report **2 балла**
# * графики обучения обязательно должны присутствовать
#
# **NOTE**: рядом лежит ноутбук с baseline solution, вы можете отталкиваться от него, если хотите.

# %%
class VGG16(pl.LightningModule):
    def __init__(self, num_classes, lr=2e-4, num_epochs=10, steps_per_epoch=35, div_factor=1e+3):
        super().__init__()
        self.save_hyperparameters()
        self.num_epochs = num_epochs
        self.steps_per_epoch = steps_per_epoch
        self.div_factor = div_factor
        self.lr = lr
        self.num_classes = num_classes
        self.model = nn.Sequential(
          nn.Conv2d(3, 64, 3, padding=1),
          nn.ReLU(),
          nn.Conv2d(64, 64, 3, padding=1),
          nn.ReLU(),
          nn.MaxPool2d(2, 2),
          nn.Conv2d(64, 128, 3, padding=1),
          nn.ReLU(),
          nn.Conv2d(128, 128, 3, padding=1),
          nn.ReLU(),
          nn.MaxPool2d(2, 2),
          nn.Conv2d(128, 256, 3, padding=1),
          nn.ReLU(),
          nn.Conv2d(256, 256, 3, padding=1),
          nn.ReLU(),
          nn.Conv2d(256, 256, 3, padding=1),
          nn.ReLU(),
          nn.MaxPool2d(2, 2),
          nn.Conv2d(256, 512, 3, padding=1),
          nn.ReLU(),
          nn.Conv2d(512, 512, 3, padding=1),
          nn.ReLU(),
          nn.Conv2d(512, 512, 3, padding=1),
          nn.ReLU(),
          nn.MaxPool2d(2, 2),
          nn.Conv2d(512, 512, 3, padding=1),
          nn.ReLU(),
          nn.Conv2d(512, 512, 3, padding=1),
          nn.ReLU(),
          nn.Conv2d(512, 512, 3, padding=1),
          nn.ReLU(),
          nn.MaxPool2d(2, 2),
          nn.Flatten(),
          nn.Linear(25088, 4096),
          nn.Dropout(p=0.5),
          nn.ReLU(),
          nn.Linear(4096, 4096),
          nn.Dropout(p=0.5),
          nn.ReLU(),
          nn.Linear(4096, num_classes)
        )
        self.loss_fn = nn.CrossEntropyLoss()
        self.accuracy = Accuracy(task="multiclass", num_classes=num_classes)
        
    def forward(self, x):
        x = self.model(x)
        return x
    
    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=self.lr)
        scheduler = torch.optim.lr_scheduler.OneCycleLR(
            optimizer=optimizer,
            epochs=self.num_epochs,
            steps_per_epoch=self.steps_per_epoch,
            max_lr=self.lr,
            pct_start=0.1,
            anneal_strategy='linear',
            final_div_factor=self.div_factor
        )
        return [optimizer], [scheduler]
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        loss = self.loss_fn(preds, y)
        acc = self.accuracy(torch.argmax(preds, dim=1), y)
        self.log('train_loss', loss.item(), on_step=False, on_epoch=True, logger=True)
        self.log('train_acc', acc, on_step=False, on_epoch=True, logger=True)
        return loss
    
    def validation_step(self, batch, batch_idx):
        x,y = batch
        preds = self(x)
        loss = self.loss_fn(preds, y)
        acc = self.accuracy(torch.argmax(preds, dim=1), y)
        self.log('val_loss', loss, on_epoch=True, prog_bar=True, logger=True)
        self.log('val_acc', acc, on_epoch=True, prog_bar=True, logger=True)
        
    def test_step(self, batch, batch_idx):
        x,y = batch
        preds = self(x)
        acc = self.accuracy(torch.argmax(preds, dim=1), y)
        self.log('test_acc', acc, on_epoch=True, prog_bar=True)

# %% [markdown]
# # Downloaded models

# %%
class ResNet50(pl.LightningModule):
    def __init__(self, num_classes, lr=2e-4):
        super().__init__()
        self.save_hyperparameters()
        self.lr = lr
        self.num_classes = num_classes
        self.model = models.resnet50(weights="IMAGENET1K_V2")
        in_feat = list(self.model.children())[-1].in_features
        self.model.fc = nn.Linear(in_feat, num_classes)
        
        self.loss_fn = nn.CrossEntropyLoss()
        self.accuracy = Accuracy(task="multiclass", num_classes=self.num_classes)
        
    def forward(self, x):
        x = self.model(x)
        return x
    
    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=self.lr)
        return optimizer
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        loss = self.loss_fn(preds, y)
        acc = self.accuracy(torch.argmax(preds, dim=1), y)
        self.log('train_loss', loss.item(), on_step=False, on_epoch=True, logger=True)
        self.log('train_acc', acc, on_step=False, on_epoch=True, logger=True)
        return loss
    
    def validation_step(self, batch, batch_idx):
        x,y = batch        
        preds = self(x)
        loss = self.loss_fn(preds, y)
        acc = self.accuracy(torch.argmax(preds, dim=1), y)
        self.log('val_loss', loss, on_epoch=True, prog_bar=True, logger=True)
        self.log('val_acc', acc, on_epoch=True, prog_bar=True, logger=True)
        
    def test_step(self, batch, batch_idx):
        x,y = batch
        preds = self(x)
        acc = self.accuracy(torch.argmax(preds, dim=1), y)
        self.log('test_acc', acc, on_epoch=True,prog_bar=True)

# %%
class InceptionV3(pl.LightningModule):
    def __init__(self, num_classes, lr=2e-4):
        super().__init__()
        self.save_hyperparameters()
        self.lr = lr
        self.num_classes = num_classes
        self.model = models.inception_v3(weights="IMAGENET1K_V1")
        self.model.AuxLogits.fc = nn.Linear(768, num_classes)
        self.model.fc = nn.Linear(2048, num_classes)
        self.loss_fn = nn.CrossEntropyLoss()
        self.accuracy = Accuracy(task="multiclass", num_classes=self.num_classes)
        
    def forward(self, x):
        x = self.model(x)
        return x
    
    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=self.lr)
        return optimizer
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        outputs, aux_outputs = self(x)
        loss1 = self.loss_fn(outputs, y)
        loss2 = self.loss_fn(aux_outputs, y)
        loss = loss1 + 0.4*loss2
        acc = self.accuracy(torch.argmax(outputs, dim=1), y)
        self.log('train_loss', loss.item(), on_step=False, on_epoch=True, logger=True)
        self.log('train_acc', acc, on_step=False, on_epoch=True, logger=True)
        return loss
    
    def validation_step(self, batch, batch_idx):
        x,y = batch        
        preds = self(x)
        loss = self.loss_fn(preds, y)
        acc = self.accuracy(torch.argmax(preds, dim=1), y)
        self.log('val_loss', loss, on_epoch=True, prog_bar=True, logger=True)
        self.log('val_acc', acc, on_epoch=True, prog_bar=True, logger=True)
        
    def test_step(self, batch, batch_idx):
        x,y = batch
        preds = self(x)
        acc = self.accuracy(torch.argmax(preds, dim=1), y)
        self.log('test_acc', acc, on_epoch=True,prog_bar=True)

# %% [markdown]
# # Train

# %% [markdown]
# ## From zero

# %%
vgg_model = VGG16(num_classes = 10, 
              num_epochs = CONFIG['epochs'], 
              steps_per_epoch = len(train_dl),
              lr = CONFIG['lr'],
              div_factor = CONFIG['div_factor'])
vgg_checkpoint_callback = ModelCheckpoint(filename='best-{epoch}', monitor='val_acc',mode='max', save_top_k=1)
trainer_args = {
        "accelerator": "gpu",
        "max_epochs": CONFIG['epochs'],
        "default_root_dir": "vgg16/",
        "callbacks": vgg_checkpoint_callback
    }
trainer = pl.Trainer(**trainer_args, enable_progress_bar=True)
trainer.fit(vgg_model, train_dl, val_dl)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type               | Params
# ------------------------------------------------
# 0 | model    | Sequential         | 134 M
# 1 | loss_fn  | CrossEntropyLoss   | 0
# 2 | accuracy | MulticlassAccuracy | 0
# ------------------------------------------------
# 134 M     Trainable params
# 0         Non-trainable params
# 134 M     Total params
# 537.206   Total estimated model params size (MB)
# ...

# %% [markdown]
# ## Fine-tuning

# %%
resnet_model = ResNet50(num_classes = 10, lr = 2e-4)
resnet_checkpoint_callback = ModelCheckpoint(filename='best-{epoch}', monitor='val_acc',mode='max', save_top_k=1)
resnet_trainer_args = {
        "accelerator": "gpu",
        "max_epochs": 7,
        "default_root_dir": "resnet50/",
        "callbacks": resnet_checkpoint_callback
    }
resnet_trainer = pl.Trainer(**resnet_trainer_args, enable_progress_bar=True)
resnet_trainer.fit(resnet_model, resnet_train_dl, resnet_val_dl)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type               | Params
# ------------------------------------------------
# 0 | model    | ResNet             | 23.5 M
# 1 | loss_fn  | CrossEntropyLoss   | 0
# 2 | accuracy | MulticlassAccuracy | 0
# ------------------------------------------------
# 23.5 M    Trainable params
# 0         Non-trainable params
# 23.5 M    Total params
# 94.114    Total estimated model params size (MB)
# ...

# %%
inception_model = InceptionV3(num_classes = 10, lr = 2e-4)
inception_checkpoint_callback = ModelCheckpoint(filename='best-{epoch}', monitor='val_acc',mode='max', save_top_k=1)
inception_trainer_args = {
        "accelerator": "gpu",
        "max_epochs": 7,
        "default_root_dir": "inception/",
        "callbacks": inception_checkpoint_callback
    }
inception_trainer = pl.Trainer(**inception_trainer_args, enable_progress_bar=True)
inception_trainer.fit(inception_model, inception_train_dl, inception_val_dl)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type               | Params
# ------------------------------------------------
# 0 | model    | Inception3         | 24.4 M
# 1 | loss_fn  | CrossEntropyLoss   | 0
# 2 | accuracy | MulticlassAccuracy | 0
# ------------------------------------------------
# 24.4 M    Trainable params
# 0         Non-trainable params
# 24.4 M    Total params
# 97.486    Total estimated model params size (MB)
# ...

# %% [markdown]
# # Test and metrics

# %%
metrics_list = ['train_loss', 'train_acc', 'val_loss', 'val_acc']

# %%
from pathlib import Path
import re


def get_version(path: Path):
    pattern = re.compile(r'version_(\d+)$')
    match = pattern.match(str(path.name))
    if match is not None:
        return int(match.group(1))
    return -1

def get_most_recent_tensorboard_log_and_ckpt(root_path = "./"):
    root_path = Path(root_path)
    log_dirs = sorted([(get_version(p), p) for p in root_path.iterdir() if p.is_dir()])
    last_version_path = log_dirs[-1][1]
    checkpoint_dir = last_version_path / Path("checkpoints")
    return last_version_path.__str__(), checkpoint_dir.glob("*.ckpt").__next__().__str__()

# %%
from tensorboard.backend.event_processing import event_accumulator
from typing import Iterable, Dict
import pandas as pd


def parse_tensorboard(path: str, scalars: Iterable):
    """Returns a dictionary of numpy arrays for each requested scalar"""
    ea = event_accumulator.EventAccumulator(
        path,
        size_guidance={event_accumulator.SCALARS: 0},
    )
    _absorb_print = ea.Reload()
    # make sure the scalars are in the event accumulator tags
    assert all(
        s in ea.Tags()["scalars"] for s in scalars
    ), "some scalars were not found in the event accumulator"
    return {k: pd.DataFrame(ea.Scalars(k))["value"].to_numpy() for k in scalars}

# %%
def plot_tensorboard_graphics(data: Dict[str, np.ndarray]):
    subplots = [['val_loss', 'train_loss'],
                ['val_acc', 'train_acc']]
    subplots_titles = [("История ошибки", "Ошибка"),
                       ("История точности", "Точность")]
    labels = {'train_loss': 'Train',
              'train_acc': 'Train',
              'val_loss': 'Valid',
              'val_acc': 'Valid'}

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for i, (scalar_names, (title, y_label)) in enumerate(zip(subplots, subplots_titles)):
        for name in scalar_names:
            axes[i].plot(list(range(1, 1 + len(data[name]))),
                         data[name], label=labels[name])
        
        axes[i].set_title(title)
        axes[i].set_xlabel("Эпоха")
        axes[i].set_ylabel(y_label)
        axes[i].grid(ls=':')
        axes[i].legend()
    plt.show()

# %%
@torch.no_grad()
def print_classification_report(model: nn.Module, loader: DataLoader, device='cuda:0'):
    model.to(device)
    model.eval()
    preds = []
    all_labels = []
    for inputs, labels in loader:
        inputs = inputs.to(device)
        logits = model(inputs).cpu()
        preds.extend(logits.argmax(1))
        all_labels.extend(labels)
    
    print(classification_report(all_labels, preds))

# %%
from typing import List, Tuple

def get_rgb_cell_map(float_cell_map):
    cmap = plt.cm.get_cmap('Greens')
    max_value = np.max(np.array(float_cell_map))
    rgb_cell_map = [[cmap(cell/max_value) for cell in row] for row in float_cell_map]
    return rgb_cell_map

@torch.no_grad()
def plot_confusion_matrix(model: nn.Module, loader: DataLoader, device='cuda:0') -> List[Tuple[torch.Tensor, torch.Tensor, torch.Tensor]]:
    model.to(device)
    model.eval()
    faults = []
    id2class = {i:q for q,i in loader.dataset.class_to_idx.items()}
    id2class = list(list(zip(*sorted(id2class.items())))[1])
    confusion_matrix = np.zeros((len(id2class), len(id2class)))
    for inputs, labels in loader:
        inputs, labels = inputs.to(device), labels.to(device)
        logits = model(inputs)
        preds = logits.argmax(1)
        faults += [(inputs[j].cpu(), preds[j].item(), labels[j].item()) for j in torch.where(preds != labels)[0]]
        for pred, label in zip(preds, labels):
            confusion_matrix[label][pred] += 1
    
    fig, ax = plt.subplots()
    # hide axes
    fig.patch.set_visible(False)
    ax.axis('off')
    ax.axis('tight')
    ax.table(confusion_matrix.tolist(), rowLabels=id2class, colLabels=id2class, 
             cellColours=get_rgb_cell_map(confusion_matrix.tolist()), loc='center')
    fig.tight_layout()
    plt.show()
    return faults

# %%
class2name = {
    "n0": "alouatta palliata",
    "n1": "erythrocebus patas",
    "n2": "cacajao calvus",
    "n3": "macaca fuscata",
    "n4": "cebuella pygmea",
    "n5": "cebus capucinus",
    "n6": "mico argentatus",
    "n7": "saimiri sciureus",
    "n8": "aotus nigriceps",
    "n9": "trachypithecus johnii"
}
id2name = {i:class2name[q] for i,q in id2clas.items()}

def plot_failed_predictions(failed_preds, num_images):
    samples = [failed_preds[idx] for idx in np.random.choice(np.arange(0, len(failed_preds)), num_images, replace=False)]
    images = [i[0] for i in samples]
    preds = [id2name[i[1]] for i in samples]
    labels = [id2name[i[2]] for i in samples]

    img_grid = torchvision.utils.make_grid(images, nrow=num_images, normalize=True, pad_value=0.5)
    img_grid = img_grid.permute(1, 2, 0)

    plt.figure(figsize=(8, 8))
    plt.imshow(img_grid)
    plt.axis("off")
    plt.show()
    plt.close()
    print("Predicted labels: \"{}\"".format('", "'.join(preds)))
    print("True labels: \"{}\"".format('", "'.join(labels)))

# %% [markdown]
# ## VGG 16

# %%
last_vgg_log_path, vgg_ckpt_path = get_most_recent_tensorboard_log_and_ckpt("./vgg16/lightning_logs")
log_scalars = parse_tensorboard(last_vgg_log_path, metrics_list)

# %%
plot_tensorboard_graphics(log_scalars)

# %%
vgg_model = VGG16.load_from_checkpoint(vgg_ckpt_path)
trainer.test(vgg_model, val_dl)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 3080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.8051470518112183
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_acc': 0.8051470518112183}]

# %%
print_classification_report(vgg_model, val_dl)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.73      0.76        26
#            1       0.66      0.75      0.70        28
#            2       0.90      1.00      0.95        27
#            3       0.81      0.87      0.84        30
#            4       0.82      0.54      0.65        26
#            5       0.81      0.75      0.78        28
#            6       0.83      0.92      0.87        26
#            7       0.91      0.71      0.80        28
#            8       0.80      0.89      0.84        27
#            9       0.77      0.88      0.82        26
#
#     accuracy                           0.81       272
#    macro avg       0.81      0.80      0.80       272
# weighted avg       0.81      0.81      0.80       272

# %%
vgg_faults = plot_confusion_matrix(vgg_model, val_dl)

# %%
plot_failed_predictions(vgg_faults, 4)
# Out:
# Predicted labels: "macaca fuscata", "cebus capucinus", "trachypithecus johnii", "aotus nigriceps"
# True labels: "erythrocebus patas", "alouatta palliata", "alouatta palliata", "cebus capucinus"

# %% [markdown]
# ## ResNet50

# %%
last_resnet_log_path, resnet_ckpt_path = get_most_recent_tensorboard_log_and_ckpt("./resnet50/lightning_logs")
log_scalars = parse_tensorboard(last_resnet_log_path, metrics_list)

# %%
plot_tensorboard_graphics(log_scalars)

# %%
resnet_model = ResNet50.load_from_checkpoint(resnet_ckpt_path)
resnet_trainer.test(resnet_model, resnet_val_dl)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 3080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.9852941036224365
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_acc': 0.9852941036224365}]

# %%
print_classification_report(resnet_model, resnet_val_dl)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        26
#            1       0.93      1.00      0.97        28
#            2       1.00      1.00      1.00        27
#            3       1.00      0.93      0.97        30
#            4       1.00      0.96      0.98        26
#            5       0.97      1.00      0.98        28
#            6       1.00      1.00      1.00        26
#            7       1.00      1.00      1.00        28
#            8       1.00      1.00      1.00        27
#            9       0.96      0.96      0.96        26
#
#     accuracy                           0.99       272
#    macro avg       0.99      0.99      0.99       272
# weighted avg       0.99      0.99      0.99       272

# %%
resnet_faults = plot_confusion_matrix(resnet_model, resnet_val_dl)

# %%
plot_failed_predictions(resnet_faults, 2)
# Out:
# Predicted labels: "trachypithecus johnii", "erythrocebus patas"
# True labels: "cebuella pygmea", "macaca fuscata"

# %% [markdown]
# ## InceptionV3

# %%
last_inception_log_path, inception_ckpt_path = get_most_recent_tensorboard_log_and_ckpt("./inception/lightning_logs")
log_scalars = parse_tensorboard(last_inception_log_path, metrics_list)

# %%
plot_tensorboard_graphics(log_scalars)

# %%
inception_model = InceptionV3.load_from_checkpoint(inception_ckpt_path)
inception_trainer.test(inception_model, inception_val_dl)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 3080') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.9926470518112183
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_acc': 0.9926470518112183}]

# %%
print_classification_report(inception_model, inception_val_dl)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        26
#            1       0.97      1.00      0.98        28
#            2       1.00      1.00      1.00        27
#            3       1.00      1.00      1.00        30
#            4       0.96      1.00      0.98        26
#            5       1.00      1.00      1.00        28
#            6       1.00      1.00      1.00        26
#            7       1.00      1.00      1.00        28
#            8       1.00      1.00      1.00        27
#            9       1.00      0.92      0.96        26
#
#     accuracy                           0.99       272
#    macro avg       0.99      0.99      0.99       272
# weighted avg       0.99      0.99      0.99       272

# %%
inception_faults = plot_confusion_matrix(inception_model, inception_val_dl)

# %%
plot_failed_predictions(inception_faults, 2)
# Out:
# Predicted labels: "erythrocebus patas", "cebuella pygmea"
# True labels: "trachypithecus johnii", "trachypithecus johnii"

# %% [markdown]
# # Summary

# %% [markdown]
# ## Аугментации
# Для "расширения" набора данных и уменьшения вероятности переобучения на тренировочной выборке был взят следующий набор аугментаций:
# * Горизонтальное отзеркаливание изображение — классическая аугментация для распознования изображений.
# * Поворорт изображения на $90^{\circ}$ — так как обезьяны для распознования преимущественно перемещаются по ветвям деревьев, их ориентация в пространстве не предопределена: они могут как висеть/сидеть на ветке, так и карабкаться по ней.
# * Масштабирование в $[0.8, 1.2]$ раза и поворот изображения на 20 градусов — аугментация, которая дополнительно расширяет диапазон положений обезьяны в пространстве и убирает часть фона.
#
# В ряд аугментаций не были включины изменения, направленные на цвета (яркость, контрастность и т.д.) и качество (размытие) изображения, так как, скорее всего, в этих параметрах шерсти животных скрыты ключевые признаки различия видов.
#
# В конце для передачи изображений на вход модели и её более стабильного обучения в тренировочную и тестовую выборки были добавлены аугменатации, нормализующие каналы и масштабирующие разрешение к размеру $224\times224$ пикселя.

# %% [markdown]
# ## Обучение VGG16
# Для наилучшей оптимизации модели с архитектурой VGG'16 был дополнительно применён следующий ряд методов:
# * Для того, чтобы исключить переобучение нейронной сети так же, как и в оригинальной статье, для первух двух полносвязных слоёв была добавлена регуляризация Dropout с вероятностью 0.5.
# * Вместо используемого в оригинальной статье оптимизатора был использован более совершенный AdamW.
# * Хотя в оригинальной статье learning rate уменьшался только один раз на один порядок, для текущий задачи лучше подошёл [1cycle](https://arxiv.org/abs/1708.07120) планировщик для более плавного уменьшения learning rate до в $10^5$ раз.
# * Максимальное значение learning rate $= 0.01$ из оригинальной статьи тоже оказалось слишком большим, оптимальным для текущей задачи стал learning rate $= 0.0002$.
# * Количество эпох обучения было увеличено до $200$ по $35$ шагов.

# %% [markdown]
# ## Тестирование моделей
# В процессе обучения моделей сохраняются их веса с лучшей точностью на валидационной выборке. Перед тестированием они загружаются в исследуемую модель, чтобы продемонстрировать её наилучшие показатели. Дополнительно, перед тестированием показываются графики обучения, построенные по логам, собранных в его процессе.
# Кроме подсчёта точности на тестовой выборке, в текущем ноутбуке представлен отчёт о классификации модели с основными метриками: precision, recall, f1-score для каждого класса, а также confusion matrix, описывающую типы ошибок модели.

# %% [markdown]
# ## Fine-tuning моделей
# Для сравнения с VGG'16 были использованы более новые архитектуры моделей с предварительно обученными весами: ResNet50 и InceptionV3.
# * Ключевой особенностью первой является использование "residual" блоков со  skip-connection, предотвращающим затухание или взрыв градиентов.
# * В архитектуре Inception ввели поиск паттернов изображения в "разных масштабах" и дополнительные головы для предсказания классов из промежуточных слоёв.
#
# Перед обучением моделей в них были заменены предсказываающие головы, и все оставшиеся предобученные веса при оптимизации тоже обновлялись. А в качестве алгоритма оптимизации был выбран AdamW.

# %% [markdown]
# ## Сравнение моделей
# * VGG'16
# Несмотря на приложенные усилия для избежания переобучения, во второй половине оптимизации модель демонстрирует его признаки на значениях функции потерь для тренировочной и валидационной выборок. Предположение о выучивании моделью специфичных свойств для тренировочных наборов данных подтверждается также расхождением точности модели на обучающей и валидационной выборках. При этом конечная точность модели на тренировочной выборке всё равно не превышает $95\%$. Это и сам длинный цикл обучения модели можно связать с большим количеством последовательно идущих слоёв, что может приводить к затуханию градиентов.
# Итоговая точность на тестовой выборке для VGG'16 составляет $80.5\%$. В качестве интересного факта можно заметить, что хуже всего модель, согласно recall $\approx 0.54$, научилась предсказывать четвёртый класс "Cebuella pygmea", чаще всего путая его с "Aotus nigriceps".
# * ResNet50 и InceptionV3
# Благодаря загруженным весам предобученные модели прошли большую часть обучения за первую эпоху. При этом можно заметить, что нейронные сети при первой же проверке на валидационных данных продемонстрировали почти полное понимание отличительных признаков всех видов обезьян, а весь оставшийся цикл обучения доучивали особенности тренировочной выборки. Особенно явно это видно на примере обучения InceptionV3.
# Итоговая точность моделей составила $98.5\%$ и $99.3\%$, соответсвенно, а recall для каждого класса оказался не ниже $0.92$. Можно считать, что предобученные нейронные сети полностью справились с поставленной задачей, а полученные ошибки находятся в пределах погрешности.
